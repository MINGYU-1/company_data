# %%
import pandas as pd
df1 = pd.read_csv('../data_csv/11_10/강원도_모범음식점.csv',encoding = 'CP949')
# 춘천시만 뽑는 방법
df2 = df1[df1['시군구'] =='춘천시']
df2['시군구'].value_counts()
# Out:
# 시군구
# 춘천시    107
# Name: count, dtype: int64
