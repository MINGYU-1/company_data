# %%
import pandas as pd
df1 = pd.read_csv('../data_csv/11_11/주민등록인구및세대.csv',encoding ='CP949')
df1.columns.to_list()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   행정구역             18 non-null     object
#  1   2025년10월_총인구수    18 non-null     object
#  2   2025년10월_세대수     18 non-null     object
#  3   2025년10월_세대당 인구  18 non-null     float64
#  4   2025년10월_남자 인구수  18 non-null     object
#  5   2025년10월_여자 인구수  18 non-null     object
#  6   2025년10월_남여 비율   18 non-null     float64
# dtypes: float64(2), object(5)
# memory usage: 1.1+ KB
