# %%
import os
os.listdir(".")
# Out:
# ['강원도.docx',
#  'm5_state_sales.csv',
#  '11_23_data.ipynb',
#  '11_23.ipynb',
#  '11_18_studying.ipynb',
#  'businesses',
#  '11_18_prophet.ipynb',
#  'data_csv',
#  'data_analysis',
#  'PRSA_data_2010.1.1-2014.12.31.csv',
#  '11_18_practice.ipynb',
#  '11_23_rename_yr.ipynb',
#  '.DS_Store',
#  'example_wp_log_R.csv',
#  '의원.ipynb',
#  '11_23_rename.ipynb',
#  'example_wp_log_peyton_manning.csv',
#  'analyzing_mysql']

# %%
df = pd.read_csv("./data_csv/강원특별자치도_식품자동판매기업.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df = pd.read_csv("./data_csv/강원특별자치도_식품자동판매기업.csv")
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
import pandas as pd
df = pd.read_csv("/workspaces/company_data/second_week/data_csv/강원특별자치도_식품자동판매기업.csv", encoding="cp949")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("/workspaces/company_data/second_week/data_csv/강원특별자치도_식품자동판매기업.csv", encoding="cp949")
#
# ...

# %%
for f in os.listdir("data_csv"):
    print(repr(f))
# Out:
# '강원특별자치도_식품자동판매기업.csv'
# '강원특별자치도_쓰레기종량제봉투판매업.csv'
# '강원특별자치도_동물미용업.csv'
# '강원특별자치도_방문판매업.csv'
# '강원특별자치도_전통사찰.csv'
# '강원특별자치도_상조업.csv'
# '강원특별자치도_후원방문판매업체.csv'
# '강원특별자치도_석유판매업.csv'
# '강원특별자치도_단란주점영업.csv'
# '강원특별자치도_식품소분업.csv'
# '강원특별자치도_출판사.csv'
# '강원특별자치도_축산물보관업.csv'
# '강원특별자치도_종합테마파크업.csv'
# '강원특별자치도_관광유흥음식점업.csv'
# '강원특별자치도_종합여행업.csv'
# '강원특별자치도_축산가공업.csv'
# '강원특별자치도_원목생산업.csv'
# '강원특별자치도_승강기유지관리업체.csv'
# '강원특별자치도_식용얼음판매업.csv'
# '강원특별자치도_민방위급수시설.csv'
# '강원특별자치도_계량기수리업.csv'
# '강원특별자치도_일반음식점.csv'
# ...

# %%
os.listdir("data_csv")
# Out:
# ['강원특별자치도_식품자동판매기업.csv',
#  '강원특별자치도_쓰레기종량제봉투판매업.csv',
#  '강원특별자치도_동물미용업.csv',
#  '강원특별자치도_방문판매업.csv',
#  '강원특별자치도_전통사찰.csv',
#  '강원특별자치도_상조업.csv',
#  '강원특별자치도_후원방문판매업체.csv',
#  '강원특별자치도_석유판매업.csv',
#  '강원특별자치도_단란주점영업.csv',
#  '강원특별자치도_식품소분업.csv',
#  '강원특별자치도_출판사.csv',
#  '강원특별자치도_축산물보관업.csv',
#  '강원특별자치도_종합테마파크업.csv',
#  '강원특별자치도_관광유흥음식점업.csv',
#  '강원특별자치도_종합여행업.csv',
#  '강원특별자치도_축산가공업.csv',
#  '강원특별자치도_원목생산업.csv',
#  '강원특별자치도_승강기유지관리업체.csv',
#  '강원특별자치도_식용얼음판매업.csv',
#  '강원특별자치도_민방위급수시설.csv',
#  '강원특별자치도_계량기수리업.csv',
# ...

# %%
import os
print(os.getcwd())
print(os.listdir("."))       # 현재 폴더
print(os.listdir(".."))      # 상위 폴더
# Out:
# /workspaces/company_data/second_week
# ['강원도.docx', 'm5_state_sales.csv', '11_23_data.ipynb', '11_23.ipynb', '11_18_studying.ipynb', 'businesses', '11_18_prophet.ipynb', 'data_csv', 'data_analysis', 'PRSA_data_2010.1.1-2014.12.31.csv', '11_18_practice.ipynb', '11_23_rename_yr.ipynb', '.DS_Store', 'example_wp_log_R.csv', '의원.ipynb', '11_23_rename.ipynb', 'example_wp_log_peyton_manning.csv', 'analyzing_mysql']
# ['.git', 'README.md', '.DS_Store', 'second_week', 'first_week']

# %%
print("second_week/data_csv:", os.listdir("data_csv"))
print("first_week/data_csv:", os.listdir("../first_week/data_csv"))
# Out:
# second_week/data_csv: ['강원특별자치도_식품자동판매기업.csv', '강원특별자치도_쓰레기종량제봉투판매업.csv', '강원특별자치도_동물미용업.csv', '강원특별자치도_방문판매업.csv', '강원특별자치도_전통사찰.csv', '강원특별자치도_상조업.csv', '강원특별자치도_후원방문판매업체.csv', '강원특별자치도_석유판매업.csv', '강원특별자치도_단란주점영업.csv', '강원특별자치도_식품소분업.csv', '강원특별자치도_출판사.csv', '강원특별자치도_축산물보관업.csv', '강원특별자치도_종합테마파크업.csv', '강원특별자치도_관광유흥음식점업.csv', '강원특별자치도_종합여행업.csv', '강원특별자치도_축산가공업.csv', '강원특별자치도_원목생산업.csv', '강원특별자치도_승강기유지관리업체.csv', '강원특별자치도_식용얼음판매업.csv', '강원특별자치도_민방위급수시설.csv', '강원특별자치도_계량기수리업.csv', '강원특별자치도_일반음식점.csv', '강원특별자치도_환ᄀ
# ...

# %%
df = pd.read_csv("/workspaces/company_data/second_week/data_csv/강원특별자치도_식품자동판매기업.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df = pd.read_csv("/workspaces/company_data/second_week/data_csv/강원특별자치도_식품자동판매기업.csv")
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import os
os.chdir("/workspaces/company_data/second_week")

# %%
df = pd.read_csv("data_csv/강원특별자치도_식품자동판매업.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df = pd.read_csv("data_csv/강원특별자치도_식품자동판매업.csv")
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
import os

for f in os.listdir("/workspaces/company_data/second_week/data_csv"):
    print(repr(f))
# Out:
# '강원특별자치도_식품자동판매기업.csv'
# '강원특별자치도_쓰레기종량제봉투판매업.csv'
# '강원특별자치도_동물미용업.csv'
# '강원특별자치도_방문판매업.csv'
# '강원특별자치도_전통사찰.csv'
# '강원특별자치도_상조업.csv'
# '강원특별자치도_후원방문판매업체.csv'
# '강원특별자치도_석유판매업.csv'
# '강원특별자치도_단란주점영업.csv'
# '강원특별자치도_식품소분업.csv'
# '강원특별자치도_출판사.csv'
# '강원특별자치도_축산물보관업.csv'
# '강원특별자치도_종합테마파크업.csv'
# '강원특별자치도_관광유흥음식점업.csv'
# '강원특별자치도_종합여행업.csv'
# '강원특별자치도_축산가공업.csv'
# '강원특별자치도_원목생산업.csv'
# '강원특별자치도_승강기유지관리업체.csv'
# '강원특별자치도_식용얼음판매업.csv'
# '강원특별자치도_민방위급수시설.csv'
# '강원특별자치도_계량기수리업.csv'
# '강원특별자치도_일반음식점.csv'
# ...

# %%
import os

for f in os.listdir("data_csv"):
    print(repr(f))
# Out:
# '강원특별자치도_식품자동판매기업.csv'
# '강원특별자치도_쓰레기종량제봉투판매업.csv'
# '강원특별자치도_동물미용업.csv'
# '강원특별자치도_방문판매업.csv'
# '강원특별자치도_전통사찰.csv'
# '강원특별자치도_상조업.csv'
# '강원특별자치도_후원방문판매업체.csv'
# '강원특별자치도_석유판매업.csv'
# '강원특별자치도_단란주점영업.csv'
# '강원특별자치도_식품소분업.csv'
# '강원특별자치도_출판사.csv'
# '강원특별자치도_축산물보관업.csv'
# '강원특별자치도_종합테마파크업.csv'
# '강원특별자치도_관광유흥음식점업.csv'
# '강원특별자치도_종합여행업.csv'
# '강원특별자치도_축산가공업.csv'
# '강원특별자치도_원목생산업.csv'
# '강원특별자치도_승강기유지관리업체.csv'
# '강원특별자치도_식용얼음판매업.csv'
# '강원특별자치도_민방위급수시설.csv'
# '강원특별자치도_계량기수리업.csv'
# '강원특별자치도_일반음식점.csv'
# ...
