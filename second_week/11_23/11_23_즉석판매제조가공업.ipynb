# %%
import pandas as pd

data = pd.read_csv('./data_csv/강원특별자치도_즉석판매제조가공업.csv', encoding='cp949')
# Out:
# /var/folders/sc/_dk299z14xs6j6n9ggl_ny5r0000gn/T/ipykernel_10435/3177806772.py:3: DtypeWarning: Columns (31,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('./data_csv/강원특별자치도_즉석판매제조가공업.csv', encoding='cp949')
