# %% [markdown]
# ## https://www.localdata.go.kr/devcenter/dataDown.do?menuNo=20001

# %%
import pandas as pd
df = pd.read_csv("./data_csv/강원특별자치도_08_26_05_P_후원방문판매업체.csv",encoding= 'EUC-KR')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515 entries, 0 to 514
# Data columns (total 32 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   번호               515 non-null    int64
#  1   개방서비스명           515 non-null    object
#  2   개방서비스아이디         515 non-null    object
#  3   개방자치단체코드         515 non-null    int64
#  4   관리번호             515 non-null    object
#  5   인허가일자            515 non-null    object
#  6   인허가취소일자          0 non-null      float64
#  7   영업상태구분코드         515 non-null    int64
#  8   영업상태명            515 non-null    object
#  9   상세영업상태코드         515 non-null    object
#  10  상세영업상태명          515 non-null    object
#  11  폐업일자             345 non-null    object
#  12  휴업시작일자           0 non-null      float64
#  13  휴업종료일자           0 non-null      float64
#  14  재개업일자            0 non-null      float64
#  15  소재지전화            232 non-null    float64
# ...

# %%
import os

folder = "./data_csv"   # 같은 위치의 하위폴더

csv_files = [
    f for f in os.listdir(folder)
    if f.lower().endswith(".csv")
]

print("CSV 파일 개수:", len(csv_files))
# Out:
# CSV 파일 개수: 195

# %%
import os
import pandas as pd

folder = "./data_csv"  # 상대경로

# 시도해 볼 인코딩 후보들
encoding_candidates = ["cp949", "euc-kr", "utf-8-sig", "utf-8"]

for filename in os.listdir(folder):
    if filename.lower().endswith(".csv"):
        path = os.path.join(folder, filename)

        df = None
        last_error = None

        for enc in encoding_candidates:
            try:
                df = pd.read_csv(path, encoding=enc)
                # 성공하면 enc 정보 출력해도 좋음
                print(f"{filename} (encoding={enc}) → row 수: {len(df)}")
                break
            except UnicodeDecodeError as e:
                last_error = e
                continue

        if df is None:
            print(f"{filename} 은(는) 인코딩 문제로 읽지 못했습니다.")
            if last_error is not None:
                print("  마지막 오류:", last_error)
# Out:
# 강원특별자치도_가축분뇨배출시설관리업사업장.csv (encoding=cp949) → row 수: 22
# 강원특별자치도_가축분뇨수집운반업.csv (encoding=cp949) → row 수: 47
# 강원특별자치도_가축사육업.csv (encoding=cp949) → row 수: 14891
# 강원특별자치도_가축인공수정소.csv (encoding=cp949) → row 수: 284
# 강원특별자치도_개인하수처리시설관리업사업장.csv (encoding=cp949) → row 수: 130
# 강원특별자치도_건강기능식품유통전문판매업.csv (encoding=cp949) → row 수: 255
# 강원특별자치도_건강기능식품일반판매업.csv (encoding=cp949) → row 수: 10173
# 강원특별자치도_건물위생관리업.csv (encoding=cp949) → row 수: 1576
# 강원특별자치도_건설폐기물처리업.csv (encoding=cp949) → row 수: 261
# 강원특별자치도_게임물배급업.csv (encoding=cp949) → row 수: 18
# 강원특별자치도_게임물제작업.csv (encoding=cp949) → row 수: 63
# 강원특별자치도_계량기수리업.csv (encoding=cp949) → row 수: 27
# ...

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

summary_sorted

import os
import pandas as pd

folder = "./data_csv"

encoding_candidates = ["cp949", "euc-kr", "utf-8-sig", "utf-8"]

results = []   # ← row, filename, encoding 저장용 리스트

for filename in os.listdir(folder):
    if filename.lower().endswith(".csv"):
        path = os.path.join(folder, filename)

        df = None
        used_encoding = None

        for enc in encoding_candidates:
            try:
                df = pd.read_csv(path, encoding=enc, low_memory=False)
                used_encoding = enc
                break
            except:
                continue
        
        if df is not None:
            results.append({
                "filename": filename,
                "encoding": used_encoding,
                "rows": len(df)
            })
        else:
            results.append({
                "filename": filename,
                "encoding": "ERROR",
                "rows": None
            })

# DataFrame으로 변환
summary = pd.DataFrame(results)

# row 수 기준으로 내림차순 정렬
summary_sorted = summary.sort_values(by="rows", ascending=False)

summary_sorted
# Out:
#                                               filename encoding     rows
# 21              강원특별자치도_일반음식점.csv    cp949  98965.0
# 173              강원특별자치도_통신판매업.csv    cp949  54073.0
# 32                 강원특별자치도_담배소매업.csv    cp949  30703.0
# 59      강원특별자치도_즉석판매제조가공업.csv    cp949  21597.0
# 194               강원특별자치도_휴게음식점.csv    cp949  21178.0
# 54                강원특별자치도_가축사육업.csv    cp949  14891.0
# 103                    강원특별자치도_미용업.csv    cp949  12328.0
# 129  강원특별자치도_건강기능식품일반판ᄆ...    cp949  10173.0
# 27            강원특별자치도_농어촌민박업.csv    cp949   9678.0
# 0         강원특별자치도_식품자동판매기업.csv    cp949   7254.0
# 163              강원특별자치도_축산판매업.csv    cp949   7109.0
# 138       강원특별자치도_의료기기판매임대업.csv    cp949   5918.0
# ...
